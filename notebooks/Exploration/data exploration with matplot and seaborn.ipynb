# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
df = pd.read_csv(r"C:\Users\vishnu\fraud_detection.csv")

# %%
df.tail()
# Out:
#         Unnamed: 0  SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  \
# 307506      307506      456251       0         Cash loans           M
# 307507      307507      456252       0         Cash loans           F
# 307508      307508      456253       0         Cash loans           F
# 307509      307509      456254       1         Cash loans           F
# 307510      307510      456255       0         Cash loans           F
#
#        FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 307506            N               N             0          157500.0
# 307507            N               Y             0           72000.0
# 307508            N               Y             0          153000.0
# 307509            N               Y             0          171000.0
# 307510            N               N             0          157500.0
#
#         AMT_CREDIT  ...  FLAG_MOBIL  FLAG_EMP_PHONE FLAG_WORK_PHONE  \
# ...

# %%
df.describe(include='all')
# Out:
#            Unnamed: 0     SK_ID_CURR         TARGET NAME_CONTRACT_TYPE  \
# count   307511.000000  307511.000000  307511.000000             307511
# unique            NaN            NaN            NaN                  2
# top               NaN            NaN            NaN         Cash loans
# freq              NaN            NaN            NaN             278232
# mean    153755.000000  278180.518577       0.080729                NaN
# std      88770.923652  102790.175348       0.272419                NaN
# min          0.000000  100002.000000       0.000000                NaN
# 25%      76877.500000  189145.500000       0.000000                NaN
# 50%     153755.000000  278202.000000       0.000000                NaN
# 75%     230632.500000  367142.500000       0.000000                NaN
# max     307510.000000  456255.000000       1.000000                NaN
#
#        CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY   CNT_CHILDREN  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   307511 non-null  int64
#  1   SK_ID_CURR                   307511 non-null  int64
#  2   TARGET                       307511 non-null  int64
#  3   NAME_CONTRACT_TYPE           307511 non-null  object
#  4   CODE_GENDER                  307511 non-null  object
#  5   FLAG_OWN_CAR                 307511 non-null  object
#  6   FLAG_OWN_REALTY              307511 non-null  object
#  7   CNT_CHILDREN                 307511 non-null  int64
#  8   AMT_INCOME_TOTAL             307511 non-null  float64
#  9   AMT_CREDIT                   307511 non-null  float64
#  10  AMT_ANNUITY                  307499 non-null  float64
#  11  AMT_GOODS_PRICE              307233 non-null  float64
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                       int64
# SK_ID_CURR                       int64
# TARGET                           int64
# NAME_CONTRACT_TYPE              object
# CODE_GENDER                     object
# FLAG_OWN_CAR                    object
# FLAG_OWN_REALTY                 object
# CNT_CHILDREN                     int64
# AMT_INCOME_TOTAL               float64
# AMT_CREDIT                     float64
# AMT_ANNUITY                    float64
# AMT_GOODS_PRICE                float64
# NAME_TYPE_SUITE                 object
# NAME_INCOME_TYPE                object
# NAME_EDUCATION_TYPE             object
# NAME_FAMILY_STATUS              object
# NAME_HOUSING_TYPE               object
# REGION_POPULATION_RELATIVE     float64
# DAYS_BIRTH                       int64
# DAYS_EMPLOYED                    int64
# DAYS_REGISTRATION              float64
# DAYS_ID_PUBLISH                  int64
# OWN_CAR_AGE                    float64
# FLAG_MOBIL                       int64
# ...

# %%
df.isnull()
# Out:
#         Unnamed: 0  SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE  CODE_GENDER  \
# 0            False       False   False               False        False
# 1            False       False   False               False        False
# 2            False       False   False               False        False
# 3            False       False   False               False        False
# 4            False       False   False               False        False
# ...            ...         ...     ...                 ...          ...
# 307506       False       False   False               False        False
# 307507       False       False   False               False        False
# 307508       False       False   False               False        False
# 307509       False       False   False               False        False
# 307510       False       False   False               False        False
#
#         FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                          0
# SK_ID_CURR                          0
# TARGET                              0
# NAME_CONTRACT_TYPE                  0
# CODE_GENDER                         0
# FLAG_OWN_CAR                        0
# FLAG_OWN_REALTY                     0
# CNT_CHILDREN                        0
# AMT_INCOME_TOTAL                    0
# AMT_CREDIT                          0
# AMT_ANNUITY                        12
# AMT_GOODS_PRICE                   278
# NAME_TYPE_SUITE                  1292
# NAME_INCOME_TYPE                    0
# NAME_EDUCATION_TYPE                 0
# NAME_FAMILY_STATUS                  0
# NAME_HOUSING_TYPE                   0
# REGION_POPULATION_RELATIVE          0
# DAYS_BIRTH                          0
# DAYS_EMPLOYED                       0
# DAYS_REGISTRATION                   0
# DAYS_ID_PUBLISH                     0
# OWN_CAR_AGE                    202929
# FLAG_MOBIL                          0
# FLAG_EMP_PHONE                      0
# ...

# %%
fraud = df[df['TARGET'] == 1] 
valid = df[df['TARGET'] == 0]

# %%
print(len(fraud))
print(len(valid))
# Out:
# 24825
# 282686

# %%
fraud.columns
# Out:
# Index(['Unnamed: 0', 'SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE',
#        'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'REGION_POPULATION_RELATIVE',
#        'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH',
#        'OWN_CAR_AGE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE',
#        'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT',
#        'REGION_RATING_CLIENT_W_CITY'],
#       dtype='object')

# %%
valid.columns
# Out:
# Index(['Unnamed: 0', 'SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE',
#        'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'REGION_POPULATION_RELATIVE',
#        'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH',
#        'OWN_CAR_AGE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE',
#        'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT',
#        'REGION_RATING_CLIENT_W_CITY'],
#       dtype='object')

# %%
fraud.describe()
# Out:
#           Unnamed: 0     SK_ID_CURR   TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count   24825.000000   24825.000000  24825.0  24825.000000      2.482500e+04
# mean   153122.669164  277449.167936      1.0      0.463807      1.656118e+05
# std     88419.872831  102383.123458      0.0      0.756903      7.466770e+05
# min         0.000000  100002.000000      1.0      0.000000      2.565000e+04
# 25%     77234.000000  189555.000000      1.0      0.000000      1.125000e+05
# 50%    152100.000000  276291.000000      1.0      0.000000      1.350000e+05
# 75%    229701.000000  366050.000000      1.0      1.000000      2.025000e+05
# max    307509.000000  456254.000000      1.0     11.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  2.482500e+04   24825.000000     2.480400e+04
# mean   5.577785e+05   26481.744290     4.889724e+05
# std    3.464332e+05   12450.676999     3.116365e+05
# min    4.500000e+04    2722.500000     4.500000e+04
# ...

# %%
valid.describe()
# Out:
#           Unnamed: 0     SK_ID_CURR    TARGET   CNT_CHILDREN  \
# count  282686.000000  282686.000000  282686.0  282686.000000
# mean   153810.530210  278244.744536       0.0       0.412946
# std     88801.626805  102825.776954       0.0       0.718843
# min         1.000000  100003.000000       0.0       0.000000
# 25%     76838.250000  189103.250000       0.0       0.000000
# 50%    153896.500000  278362.500000       0.0       0.000000
# 75%    230720.750000  367241.500000       0.0       1.000000
# max    307510.000000  456255.000000       0.0      19.000000
#
#        AMT_INCOME_TOTAL    AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count      2.826860e+05  2.826860e+05  282674.000000     2.824290e+05
# mean       1.690777e+05  6.026483e+05   27163.623349     5.427368e+05
# std        1.104763e+05  4.068459e+05   14658.307178     3.737855e+05
# min        2.565000e+04  4.500000e+04    1615.500000     4.050000e+04
# ...

# %%
outlierFraction = len(fraud)/float(len(valid)) 
print(outlierFraction)
# Out:
# 0.08781828601345662

# %%
numeric_df = df.select_dtypes(include='number')
print(numeric_df)
# Out:
#         Unnamed: 0  SK_ID_CURR  TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0                0      100002       1             0          202500.0
# 1                1      100003       0             0          270000.0
# 2                2      100004       0             0           67500.0
# 3                3      100006       0             0          135000.0
# 4                4      100007       0             0          121500.0
# ...            ...         ...     ...           ...               ...
# 307506      307506      456251       0             0          157500.0
# 307507      307507      456252       0             0           72000.0
# 307508      307508      456253       0             0          153000.0
# 307509      307509      456254       1             0          171000.0
# 307510      307510      456255       0             0          157500.0
#
#         AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# ...

# %%
numeric_df.columns
# Out:
# Index(['Unnamed: 0', 'SK_ID_CURR', 'TARGET', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'FLAG_MOBIL',
#        'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT',
#        'REGION_RATING_CLIENT_W_CITY'],
#       dtype='object')

# %%
df_corr = numeric_df[['SK_ID_CURR','CNT_CHILDREN','AMT_INCOME_TOTAL','AMT_CREDIT','AMT_ANNUITY','AMT_GOODS_PRICE','REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED','DAYS_REGISTRATION','TARGET']]

# %%
df_corr.columns
# Out:
# Index(['SK_ID_CURR', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE',
#        'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'TARGET'],
#       dtype='object')

# %%
numeric = df_corr.drop(['TARGET'], axis = 1)
target =df_corr['TARGET']

# %%
print(target)
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 307506    0
# 307507    0
# 307508    0
# 307509    1
# 307510    0
# Name: TARGET, Length: 307511, dtype: int64

# %%
numeric.columns
# Out:
# Index(['SK_ID_CURR', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE',
#        'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION'],
#       dtype='object')

# %%
df_corr.columns
# Out:
# Index(['SK_ID_CURR', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE',
#        'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'TARGET'],
#       dtype='object')

# %%
corrmat = df_corr.corr() 
fig = plt.figure(figsize = (12, 12)) 
sns.heatmap(corrmat, vmax = .8, annot = True) 
plt.show()

# %%
corrmat = numeric.corr() 
fig = plt.figure(figsize = (12, 12)) 
sns.heatmap(corrmat, vmax = .8, annot = True) 
plt.show()

# %%
sns.catplot(data=df, x="AMT_INCOME_TOTAL", y="TARGET")

# %%
sns.catplot(data=df, x="TARGET", y="CNT_CHILDREN",kind='box')

# %%
sns.countplot(data=df, x="CNT_CHILDREN", hue="TARGET")

# %%
plt.scatter(numeric.CNT_CHILDREN,target)

# %%
numeric['CNT_CHILDREN'].value_counts().plot(kind='line')
plt.xlabel('CNT_CHILDREN')
plt.ylabel('target')
plt.title('Scatter Plot Example')
plt.show()

# %%
plt.scatter('CNT_CHILDREN','DAYS_EMPLOYED',color='g',marker='o')
plt.xlabel('CNT_CHILDREN')
plt.ylabel('DAYS_EMPLOYED')
plt.title('Scatter Plot Example')
plt.show()

# %%
numeric['AMT_INCOME_TOTAL'].value_counts().plot(kind='bar')
plt.xlabel('AMT_INCOME_TOTAL')
plt.ylabel('target')
plt.title('Scatter Plot Example')
plt.show()

# %%
numeric['AMT_CREDIT'].value_counts().plot(kind='line')
plt.xlabel('AMT_CREDIT')
plt.ylabel('target')
plt.title('Scatter Plot Example')
plt.show()

# %%
numeric['AMT_CREDIT'].value_counts().plot(kind='bar')
plt.xlabel('AMT_CREDIT')
plt.ylabel('target')
plt.title('Scatter Plot Example')
plt.show()

# %%
numeric['AMT_ANNUITY'].value_counts().plot(kind='line')
plt.xlabel('AMT_ANNUITY')
plt.ylabel('target')
plt.title('Scatter Plot Example')
plt.show()

# %%
numeric['AMT_ANNUITY'].value_counts().plot(kind='box')
plt.xlabel('AMT_ANNUITY')
plt.ylabel('target')

plt.show()

# %%
numeric['AMT_GOODS_PRICE'].value_counts().plot(kind='box')
plt.xlabel('AMT_GOODS_PRICE')
plt.ylabel('target')
plt.show()

# %%
numeric['AMT_GOODS_PRICE'].value_counts().plot(kind='line')
plt.xlabel('AMT_GOODS_PRICE')
plt.ylabel('target')
plt.show()

# %%
numeric['REGION_POPULATION_RELATIVE'].value_counts().plot(kind='line')
plt.xlabel('REGION_POPULATION_RELATIVE')
plt.ylabel('target')
plt.title('Scatter Plot Example')
plt.show()

# %%
numeric['REGION_POPULATION_RELATIVE'].value_counts().plot(kind='box')
plt.xlabel('REGION_POPULATION_RELATIVE')
plt.ylabel('target')
plt.show()

# %%
numeric['DAYS_BIRTH'].value_counts().plot(kind='line')
plt.xlabel('DAYS_BIRTH')
plt.ylabel('target')
plt.title('Scatter Plot Example')
plt.show()

# %%
numeric['DAYS_BIRTH'].value_counts().plot(kind='box')
plt.xlabel('DAYS_BIRTH')
plt.ylabel('target')

plt.show()

# %%
numeric['DAYS_EMPLOYED'].value_counts().plot(kind='line')
plt.xlabel('DAYS_EMPLOYED')
plt.ylabel('target')
plt.show()

# %%
numeric['DAYS_REGISTRATION'].value_counts().plot(kind='box')
plt.xlabel('DAYS_REGISTRATION')
plt.ylabel('target')

plt.show()

# %%
numeric['DAYS_REGISTRATION'].value_counts().plot(kind='line')
plt.xlabel('DAYS_REGISTRATION')
plt.ylabel('target')

plt.show()

# %%
sns.countplot(data=df, x="AMT_INCOME_TOTAL", hue="TARGET")
# Out:
# <Axes: xlabel='AMT_INCOME_TOTAL', ylabel='count'>

# %%
sns.countplot(data=df, x="AMT_CREDIT", hue="TARGET")
# Out:
# <Axes: xlabel='AMT_CREDIT', ylabel='count'>

# %%
sns.countplot(data=df, x="AMT_ANNUITY", hue="TARGET")
# Out:
# <Axes: xlabel='AMT_ANNUITY', ylabel='count'>

# %%
sns.countplot(data=df, x="AMT_GOODS_PRICE", hue="TARGET")
# Out:
# <Axes: xlabel='AMT_GOODS_PRICE', ylabel='count'>

# %%
sns.countplot(data=df, x="REGION_POPULATION_RELATIVE", hue="TARGET")
# Out:
# <Axes: xlabel='REGION_POPULATION_RELATIVE', ylabel='count'>

# %%
sns.countplot(data=df, x="DAYS_BIRTH", hue="TARGET")
# Out:
# <Axes: xlabel='DAYS_BIRTH', ylabel='count'>

# %%
sns.countplot(data=df, x="DAYS_EMPLOYED", hue="TARGET")
# Out:
# <Axes: xlabel='DAYS_EMPLOYED', ylabel='count'>

# %%
sns.countplot(data=df, x="DAYS_REGISTRATION", hue="TARGET")
# Out:
# <Axes: xlabel='DAYS_REGISTRATION', ylabel='count'>
