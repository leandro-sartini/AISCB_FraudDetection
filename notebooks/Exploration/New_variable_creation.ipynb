# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\ASUS\Desktop\Project\fraud_detection.csv")

# %%
data.describe()
# Out:
#              Column1     SK_ID_CURR         TARGET   CNT_CHILDREN  \
# count  307511.000000  307511.000000  307511.000000  307511.000000
# mean   153755.000000  278180.518577       0.080729       0.417052
# std     88770.923652  102790.175348       0.272419       0.722121
# min         0.000000  100002.000000       0.000000       0.000000
# 25%     76877.500000  189145.500000       0.000000       0.000000
# 50%    153755.000000  278202.000000       0.000000       0.000000
# 75%    230632.500000  367142.500000       0.000000       1.000000
# max    307510.000000  456255.000000       1.000000      19.000000
#
#        AMT_INCOME_TOTAL    AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count      3.075110e+05  3.075110e+05  307499.000000     3.072330e+05
# mean       1.687979e+05  5.990260e+05   27108.573909     5.383962e+05
# std        2.371231e+05  4.024908e+05   14493.737315     3.694465e+05
# min        2.565000e+04  4.500000e+04    1615.500000     4.050000e+04
# ...

# %%
object_cols = data.select_dtypes(include=['object'])
numeric_cols = data.select_dtypes(include=['int64', 'float64']).iloc[:, :13]

# Concatenate both selections
selected_columns = pd.concat([object_cols, numeric_cols], axis=1)

# Slice the DataFrame using the selected columns
datas = data[selected_columns.columns]

datas
# Out:
#        NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0              Cash loans           M            N               Y
# 1              Cash loans           F            N               N
# 2         Revolving loans           M            Y               Y
# 3              Cash loans           F            N               Y
# 4              Cash loans           M            N               Y
# ...                   ...         ...          ...             ...
# 307506         Cash loans           M            N               N
# 307507         Cash loans           F            N               Y
# 307508         Cash loans           F            N               Y
# 307509         Cash loans           F            N               Y
# 307510         Cash loans           F            N               N
#
#        NAME_TYPE_SUITE      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0        Unaccompanied               Working  Secondary / secondary special
# ...

# %%
description = datas.describe(include='all')
description
# Out:
#        NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# count              307511      307511       307511          307511
# unique                  2           3            2               2
# top            Cash loans           F            N               Y
# freq               278232      202448       202924          213312
# mean                  NaN         NaN          NaN             NaN
# std                   NaN         NaN          NaN             NaN
# min                   NaN         NaN          NaN             NaN
# 25%                   NaN         NaN          NaN             NaN
# 50%                   NaN         NaN          NaN             NaN
# 75%                   NaN         NaN          NaN             NaN
# max                   NaN         NaN          NaN             NaN
#
#        NAME_TYPE_SUITE NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# count           306219           307511                         307511
# ...

# %%
datas.dtypes
# Out:
# NAME_CONTRACT_TYPE             object
# CODE_GENDER                    object
# FLAG_OWN_CAR                   object
# FLAG_OWN_REALTY                object
# NAME_TYPE_SUITE                object
# NAME_INCOME_TYPE               object
# NAME_EDUCATION_TYPE            object
# NAME_FAMILY_STATUS             object
# NAME_HOUSING_TYPE              object
# OCCUPATION_TYPE                object
# Column1                         int64
# SK_ID_CURR                      int64
# TARGET                          int64
# CNT_CHILDREN                    int64
# AMT_INCOME_TOTAL              float64
# AMT_CREDIT                    float64
# AMT_ANNUITY                   float64
# AMT_GOODS_PRICE               float64
# REGION_POPULATION_RELATIVE    float64
# DAYS_BIRTH                      int64
# DAYS_EMPLOYED                   int64
# DAYS_REGISTRATION             float64
# DAYS_ID_PUBLISH                 int64
# dtype: object

# %%
corr = datas.corr(numeric_only=True)

mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(10, 8),dpi=100)

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True, fmt=".2f")

plt.title('Correlation Heatmap', size=12)

plt.show()

# %%
#To get the interaction effect Check if the ratio of income to credit influences the target..
def create_new_feature(row):
    # Example: Concatenate values from two existing columns to create a new feature
    new_feature_value = row['AMT_INCOME_TOTAL'] / row['AMT_CREDIT']
    return new_feature_value

# Apply the function to create the new feature for each row in the DataFrame
datas.loc[:, 'INCOME_TO_CREDIT_RATIO'] = datas.apply(create_new_feature, axis=1)

# %%
#Converting the DAYS_BIRTH feature to age and check if it has a different impact on the target.
def create_new_features(row):
    # Example: Concatenate values from two existing columns to create a new feature
    new_feature_values = row['DAYS_BIRTH'] // 365
    return new_feature_values

# Apply the function to create the new feature for each row in the DataFrame
datas.loc[:, 'AGE'] = datas.apply(create_new_features, axis=1)

# %%
corr = datas.corr(numeric_only=True)

mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(10, 8),dpi=100)

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True, fmt=".2f")

plt.title('Correlation Heatmap', size=12)

plt.show()
